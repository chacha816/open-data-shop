# %%
# %pwd
# Out:
# 'C:\\Users\\차소영'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: Windows
#  볼륨 일련 번호: 94BA-FDA7
#
#  C:\Users\차소영 디렉터리
#
# 2018-08-09  오후 04:01    <DIR>          .
# 2018-08-09  오후 04:01    <DIR>          ..
# 2018-07-31  오후 04:17    <DIR>          .atom
# 2018-08-09  오후 03:58            11,583 .bash_history
# 2018-07-12  오후 11:17    <DIR>          .conda
# 2017-10-09  오후 09:13    <DIR>          .eclipse
# 2018-07-09  오후 02:01    <DIR>          .gem
# 2018-06-29  오후 06:24               147 .gitconfig
# 2018-08-09  오후 04:01    <DIR>          .ipynb_checkpoints
# 2018-07-12  오후 10:34    <DIR>          .ipython
# 2017-10-09  오후 09:13    <DIR>          .jmc
# 2018-07-25  오전 12:22    <DIR>          .jupyter
# 2018-07-12  오후 10:38    <DIR>          .matplotlib
# 2018-04-10  오후 05:41    <DIR>          .spss
# 2018-07-06  오후 01:00    <DIR>          .ssh
# 2018-08-07  오후 02:11            13,535 .viminfo
# 2018-08-09  오전 10:38    <DIR>          .virtualenvs
# 2018-07-12  오후 11:38         1,963,844 2017 캐글 설문조사 분석
# ...

# %%
import pandas as pd

# %%
df_shop = pd.read_csv('project/open-data-shop/shop_201806_03.csv', encoding = 'cp949')
# Out:
# C:\Anaconda3\envs\python3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_shop.shape
# Out:
# (753114, 39)

# %%
df_shop.head(10)
# Out:
#      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0  28482144    부뚜막삼겹살  NaN         Q       음식       Q01            한식
# 1  28497846    나이키영통점  영통점         D       소매       D05          의복의류
# 2  28499066  눈빛안경.콘택트  NaN         D       소매       D18  사진/광학/정밀기기소매
# 3  28493571       설국장  NaN         O       숙박       O02     모텔/여관/여인숙
# 4  28518376    파고망화장품  NaN         D       소매       D16         화장품소매
# 5  28492408       멘토바  NaN         Q       음식       Q09          유흥주점
# 6  28486109  데일리킹스다이너  NaN         Q       음식       Q06            양식
# 7  28510140   하늘땅별땅펜션  NaN         O       숙박       O03      캠프/별장/펜션
# 8  28499466      리스안경  NaN         D       소매       D18  사진/광학/정밀기기소매
# 9  28483292   제부도그린횟집  NaN         Q       음식       Q03        일식/수산물
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드    ...                         건물관리번호  \
# 0    Q01A02     갈비/삼겹살   I56111    ...      4173025022100420000057910
# ...

# %%
df_bread = df_seoul.loc[
    df_seoul['상호명'].str.contains('뚜레쥬르|파리(바게|크라상)') &
    (~df_bread['상호명'].str.contains('파스쿠찌|잠바주스'))
].copy()
# 파스쿠찌 상호명에 파리크라상이 들어가기 때문에 파스쿠찌는 제외합니다.
df_bread.shape
